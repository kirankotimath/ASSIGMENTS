# %%
import pandas as pd

# %%
review = pd.read_csv("C:\\Users\\kiran\\Downloads\\gamestop_product_reviews_dataset_sample.csv")
review
# Out:
#                                                     url  \
# 0     https://www.gamestop.com/electronics/tvs-monit...
# 1     https://www.gamestop.com/electronics/tvs-monit...
# 2     https://www.gamestop.com/electronics/tvs-monit...
# 3     https://www.gamestop.com/electronics/tvs-monit...
# 4     https://www.gamestop.com/electronics/tvs-monit...
# ...                                                 ...
# 4681  https://www.gamestop.com/video-games/retro-gam...
# 4682  https://www.gamestop.com/video-games/xbox-one/...
# 4683  https://www.gamestop.com/video-games/xbox-one/...
# 4684  https://www.gamestop.com/video-games/xbox-one/...
# 4685  https://www.gamestop.com/video-games/xbox-one/...
#
#                                                   name         brand     sku  \
# 0     VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1         VIZIO  328244
# 1     VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1         VIZIO  328244
# 2     VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1         VIZIO  328244
# 3     VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1         VIZIO  328244
# 4     VIZIO 55-in Class OLED 4K HDR Smart TV OLED55-H1         VIZIO  328244
# ...                                                ...           ...     ...
# 4681     Mortal Kombat Vs. DC Universe - PlayStation 3  Midway Games  930223
# 4682                        Forza Horizon 4 - Xbox One     Microsoft  173787
# 4683                        Forza Horizon 4 - Xbox One     Microsoft  173787
# 4684                        Forza Horizon 4 - Xbox One     Microsoft  173787
# 4685                        Forza Horizon 4 - Xbox One     Microsoft  173787
#
#           reviewer_name                                    review_title  \
# 0               Leeford                                             NaN
# 1                  DJM7                           Great looking screen!
# 2                  EC82                                         Quality
# 3                 Weeto                   Unbelievable picture quality!
# 4            LexusSC400                                      Vizio OLED
# ...                 ...                                             ...
# 4681            Ash1986                                     Great game!
# 4682  AarontheBarbarian                You Should Race to get This Game
# 4683             Edmo72                          First time Forza owner
# 4684             m dumb  I give it a 9 out of ten. Best racer out there
# 4685   Curtiss Besinger                                         Forza 4
#
#                                      review_description  \
# 0     My new OLED is a upgrade and it's great!  This...
# 1     Rating is really a 4.5 but that's unavailable....
# 2     I’m quite pleased with the entire product as a...
# 3     I’ve only had my new Visio OLED65 mounted and ...
# 4     The picture is very crisp and the blacks very ...
# ...                                                 ...
# 4681  Super fun to play. Exactly what I wanted it to...
# 4682  I absolutely love this game. I consider myself...
# 4683  Love the game. First time owning a Forza game....
# 4684  Great game but more of the same. Graphics are ...
# 4685  Great racing game for driving fun! Would recom...
#
#                       recommended_review   verifed_purchaser  helpful_count  \
# 0          yes: I recommend this product                 NaN              0
# 1          yes: I recommend this product                 NaN              0
# 2          yes: I recommend this product                 NaN              0
# 3          yes: I recommend this product                 NaN              0
# 4          yes: I recommend this product                 NaN              0
# ...                                  ...                 ...            ...
# 4681       yes: I recommend this product  Verified Purchaser              2
# 4682  No: I don’t recommend this product  Verified Purchaser              0
# 4683  No: I don’t recommend this product  Verified Purchaser              0
# 4684  No: I don’t recommend this product  Verified Purchaser              0
# 4685  No: I don’t recommend this product  Verified Purchaser              0
#
#       not_helpful_count    reviewed_at images  rating  average_rating  \
# 0                     0  10 months ago    NaN     5.0          4.2727
# 1                     0  10 months ago    NaN     4.0          4.2727
# 2                     0  10 months ago    NaN     4.0          4.2727
# 3                     0  10 months ago    NaN     2.0          4.2727
# 4                     0  10 months ago    NaN     5.0          4.2727
# ...                 ...            ...    ...     ...             ...
# 4681                  0    3 years ago    NaN     5.0          4.1152
# 4682                  0    2 years ago    NaN     5.0          4.5827
# 4683                  0    2 years ago    NaN     5.0          4.5827
# 4684                  0    2 years ago    NaN     4.0          4.5827
# 4685                  0    2 years ago    NaN     5.0          4.5827
#
#       reviews_count                                       reviews_link  \
# 0               363  https://www.gamestop.com/on/demandware.store/S...
# 1               363  https://www.gamestop.com/on/demandware.store/S...
# 2               363  https://www.gamestop.com/on/demandware.store/S...
# 3               363  https://www.gamestop.com/on/demandware.store/S...
# 4               363  https://www.gamestop.com/on/demandware.store/S...
# ...             ...                                                ...
# 4681            217  https://www.gamestop.com/on/demandware.store/S...
# 4682           1251  https://www.gamestop.com/on/demandware.store/S...
# 4683           1251  https://www.gamestop.com/on/demandware.store/S...
# 4684           1251  https://www.gamestop.com/on/demandware.store/S...
# 4685           1251  https://www.gamestop.com/on/demandware.store/S...
#
#       comment_id                               uniq_id           scraped_at
# 0      229196240  d749678d-aeba-5a6b-b8e2-8d2121463672  16/01/2022 16:17:56
# 1      229179703  9f20312c-1047-5824-97d2-d5563b8fd046  16/01/2022 16:17:56
# 2      229174444  178b3b03-2c56-5abc-a016-c74c2633c9c2  16/01/2022 16:17:56
# 3      229167959  16e925e3-1e59-537e-aa67-1675b613d351  16/01/2022 16:17:56
# 4      229131414  bc017585-3bc1-5a37-9e58-f0bed6de9a72  16/01/2022 16:17:56
# ...          ...                                   ...                  ...
# 4681   123228799  f24f992c-bf96-5d3e-928a-0376616019e4  16/01/2022 16:19:31
# 4682   127817060  1eaba7e7-b082-52ac-9cc8-b8c6bd6f5760  16/01/2022 16:19:31
# 4683   127767426  70b90e67-ab5d-50ee-954d-8e6c52daf714  16/01/2022 16:19:31
# 4684   127688619  80f8f8db-1349-5adc-bbd9-d8ac0422b35a  16/01/2022 16:19:31
# 4685   127486613  9c205c2a-b570-5b3d-9f70-489501f86fca  16/01/2022 16:19:31
#
# [4686 rows x 20 columns]

# %%
reviews = pd.DataFrame()
reviews['x'] = review.review_description 
reviews
# Out:
#                                                       x
# 0     My new OLED is a upgrade and it's great!  This...
# 1     Rating is really a 4.5 but that's unavailable....
# 2     I’m quite pleased with the entire product as a...
# 3     I’ve only had my new Visio OLED65 mounted and ...
# 4     The picture is very crisp and the blacks very ...
# ...                                                 ...
# 4681  Super fun to play. Exactly what I wanted it to...
# 4682  I absolutely love this game. I consider myself...
# 4683  Love the game. First time owning a Forza game....
# 4684  Great game but more of the same. Graphics are ...
# 4685  Great racing game for driving fun! Would recom...
#
# [4686 rows x 1 columns]

# %%
# Above are the reviews of the product from e-commers website :-

# %%
import pandas as pd
import numpy as np
import string
import spacy

import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
from wordcloud import wordcloud
# %matplotlib inline

# %%
# to remove the space at the starting and ending of each review
reviews = [i.strip() for i in reviews.x]

# to remove the empty review
reviews= [x for x in book if x]

# %%
text = ' '.join(reviews)

# %% [markdown]
# # removing punctuation :-

# %%
no_punc_text = text.translate(str.maketrans('','',string.punctuation))

# %%
no_punc_text.lower()
# Out:
# 'my new oled is a upgrade and its great  this is my third vizio tv to replace my first one that went blank after 12 years of stellar service im even thinking of getting it repaired if possible for the great grand kids   i have always liked the picture quality and the price of vizios you cant go wrong rating is really a 45 but thats unavailable the unit looks great both in and off it is short on physical features bluetooth and whatnot but i use both external sound and media units this is a great oled to buy if you want a great tv at a reasonable price i’m quite pleased with the entire product as a whole the quality of picture and sound really speaks for itself when in use i’ve only had my new visio oled65 mounted and operating for 3 days now and i’m like a kid who after christmas can’t get enough of his favorite gift the brightness and clarity of the picture is another huge by step forward in the evolution of  the television i find myself seeking out programming that will showcase the quality of the picture regardless of the genre or intended audience some of the newer computer generated cartoons lack any redeemable qualities imho save for the incredible graphics which are stunningly colorful bright and almost as vivid as real life nature documentaries and shows involving space especially when shot in 4k are almost mesmerizing when i bought my 65” hd tv about 10 years ago i thought i was witnessing the best quality picture that could be produced by anything this side of a mirror i was wrong and happily so if you’re on the fence like i was about whether to replace a broken or outdated television with another of similar hd quality that is to say “standard high definition”don’t even waste your time it’s increasingly difficult to find as 4k is becoming ubiquitous so that is pretty much a given on the subject of spending your hard earned money on the more expensive oled technologyif you have the means or can somehow figure out how to acquire the meansmy advice is definitely do so whether you’re into movies sports gaming or even naturespace shows you will be amazed at the latest leap in picture quality and brightness and vizio offers all the quality at a substantial savings putting the absolute best technology within the reach of those of us for whom the strength of the stock market makes absolutely no difference to our bottom line \r\nfyithe 65” hd television i had to replace was a samsung that was about 4 or 5 years old that stopped working after some loud cracking and popping noises that sounded like the transformer on an overhead power line blowing out however my 42” vizio that i bought in ‘08 doesn’t even have a single bad pixel food for thought the picture is very crisp and the blacks very dark  beautiful color  the vizio smartcast app is fantastic  the response from selections is much faster than the traditional supplied remote  they update it from time to time with most recent voice search function picture quality is amazing however within a week from purchasing the tv will not turn on unless i unplug and plug it back in image is so clear i feel like i’m on the set of the shows i purchased this tv about 2 weeks ago and am blown away by the crisp 4k picture  i would definitely recommend this tv to someone considering an upgrade i got this today 225 for my birthday present from my son as a surprise gift without any prior guess or information at all my previous one in my master bed room was quite old samsung 50” pd tv which was ok but heavy and bulky compared to this \r\ni am so happy to have this wonderful big one for my first oled tv of which screen is fantastic and very light compared to my previous one indeed best price on an oled tv has a great picture and is easy to navigate the menus and connect via apple or android devices i always bought lg oled tvs because i liked their quality and features but so far vizio is just as good and a better price just like the elite controller v2 but halo edition one of the best controllers ...

# %% [markdown]
# # Tokenization :-

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
text_tokens = word_tokenize(no_punc_text)
text_tokens[0:10]
# Out:
# ['My', 'new', 'OLED', 'is', 'a', 'upgrade', 'and', 'its', 'great', 'This']

# %% [markdown]
# # Removing Stop-Words :-

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kiran\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
my_stop_words = stopwords.words('english')

# %%
no_stop_token = [word.lower() for word in text_tokens if not word.lower() in my_stop_words]

# %%
no_stop_token[0:10]
# Out:
# ['new',
#  'oled',
#  'upgrade',
#  'great',
#  'third',
#  'vizio',
#  'tv',
#  'replace',
#  'first',
#  'one']

# %%
from wordcloud import WordCloud , STOPWORDS

def plot_cloud(wordcloud):
    plt.figure(figsize=(40,30))
    plt.imshow(wordcloud)
    plt.axis('off');

# %%
stopwords=STOPWORDS
stopwords.add('game')


wordcloud = WordCloud(width=3000, height=2000,stopwords=stopwords ,background_color='black', max_words=100, colormap='Set2').generate(' '.join(no_stop_token))
plot_cloud(wordcloud)

# %% [markdown]
# # Sentimental Analysis :-

# %%
afinn = pd.read_csv('C:\\Users\\kiran\\Downloads\\Affin.csv',sep=',',encoding='Latin-1')
afinn
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
import nltk
from nltk import tokenize

# %%
sentences = tokenize.sent_tokenize(' '.join(reviews))
sentences[0:5]
# Out:
# ["My new OLED is a upgrade and it's great!",
#  'This is my third Vizio TV to replace my first one that went blank after 12 years of stellar service.',
#  "(I'm even thinking of getting it repaired if possible for the great grand kids.)",
#  "I have always liked the picture quality and the price of Vizio's.",
#  'You cant go wrong.']

# %%
sent_df = pd.DataFrame(sentences, columns=['sentences'])
sent_df
# Out:
#                                                sentences
# 0               My new OLED is a upgrade and it's great!
# 1      This is my third Vizio TV to replace my first ...
# 2      (I'm even thinking of getting it repaired if p...
# 3      I have always liked the picture quality and th...
# 4                                     You cant go wrong.
# ...                                                  ...
# 15509                      The game play is pretty cool.
# 15510                   Great game but more of the same.
# 15511  Graphics are superb and the racing is as real ...
# 15512                 Great racing game for driving fun!
# 15513                               Would recommend 9/10
#
# [15514 rows x 1 columns]

# %%
affinity_score = afinn.set_index('word')['value'].to_dict()

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def calculate_sentiment(text: str=None):
    sent_score=0
    if text:
        sentence=nlp(text)
        for word in sentence:
            sent_score += affinity_score.get(word.lemma_,0)
    return sent_score

# %%
# example for above :-
# to check it is working or not

calculate_sentiment(text='you are good')
# Out:
# 3

# %%
sent_df['sentiment_score'] = sent_df['sentences'].apply(calculate_sentiment)

# %%
sent_df
# Out:
#                                                sentences  sentiment_score
# 0               My new OLED is a upgrade and it's great!                3
# 1      This is my third Vizio TV to replace my first ...                0
# 2      (I'm even thinking of getting it repaired if p...                6
# 3      I have always liked the picture quality and th...                2
# 4                                     You cant go wrong.               -2
# ...                                                  ...              ...
# 15509                      The game play is pretty cool.                2
# 15510                   Great game but more of the same.                3
# 15511  Graphics are superb and the racing is as real ...                5
# 15512                 Great racing game for driving fun!                7
# 15513                               Would recommend 9/10                2
#
# [15514 rows x 2 columns]

# %%
sent_df['words'] = sent_df['sentences'].str.split().apply(len)

# %%
sent_df['index'] = pd.Series(range(1,15515))
sent_df
# Out:
#                                                sentences  sentiment_score  \
# 0               My new OLED is a upgrade and it's great!                3
# 1      This is my third Vizio TV to replace my first ...                0
# 2      (I'm even thinking of getting it repaired if p...                6
# 3      I have always liked the picture quality and th...                2
# 4                                     You cant go wrong.               -2
# ...                                                  ...              ...
# 15509                      The game play is pretty cool.                2
# 15510                   Great game but more of the same.                3
# 15511  Graphics are superb and the racing is as real ...                5
# 15512                 Great racing game for driving fun!                7
# 15513                               Would recommend 9/10                2
#
#        words  index
# 0          9      1
# 1         20      2
# 2         14      3
# 3         12      4
# 4          4      5
# ...      ...    ...
# 15509      6  15510
# 15510      7  15511
# 15511     12  15512
# 15512      6  15513
# 15513      3  15514
#
# [15514 rows x 4 columns]

# %%
# most positive reviews :-

sent_df[sent_df['sentiment_score']>=25]
# Out:
#                                               sentences  sentiment_score  \
# 2164  Love it great picture and sound looks great in...               25
# 2587  there is so many people that want games like a...               38
# 5895  This game is totally awesome in every way I lo...               25
# 6438  It’s awesome I loved the game I’m pretty anyon...               35
#
#       words  index
# 2164     53   2165
# 2587    164   2588
# 5895     67   5896
# 6438     95   6439

# %%
# most negative reviews :-

sent_df[sent_df['sentiment_score']<=-10]
# Out:
#                                               sentences  sentiment_score  \
# 2454  don't buy this game it is so boring bad graphi...              -11
# 5004  The draw backs would be the occasional forced ...              -10
# 5162  Not much to the game, you can’t get into an on...              -11
# 6315  The gameplay is just horrible, your punches wi...              -10
#
#       words  index
# 2454     24   2455
# 5004     50   5005
# 5162     34   5163
# 6315     62   6316

# %%
sent_df['sentiment_score'].describe()
# Out:
# count    15514.000000
# mean         1.723218
# std          2.938063
# min        -11.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max         38.000000
# Name: sentiment_score, dtype: float64

# %%
# AS MEAN IS IN POSITIVE MOST OF THE REVIEW ARE POSITIVE

# %% [markdown]
# # Visualization :-

# %%
import seaborn as sn

# %%
plt.figure(figsize=(15,8))
sn.distplot(sent_df['sentiment_score'])
# Out:
# C:\Users\kiran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_score', ylabel='Density'>

# %%
plt.figure(figsize=(18,7))
sn.lineplot(y='sentiment_score', x='index', data=sent_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='sentiment_score'>

# %%
sent_df.plot.scatter(x='words', y='sentiment_score', figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='words', ylabel='sentiment_score'>

# %%
# There is any relation betwen the no, of words and sentiment score

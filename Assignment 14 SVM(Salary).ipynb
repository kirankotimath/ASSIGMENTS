# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sal_train = pd.read_csv("C:\\Users\\kiran\\Downloads\\SalaryData_Train(1).csv")
sal_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
sal_test = pd.read_csv("C:\\Users\\kiran\\Downloads\\SalaryData_Test(1).csv")
sal_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
sal_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
sal_train.mean()
# Out:
# C:\Users\kiran\AppData\Local\Temp/ipykernel_15688/1057145405.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sal_train.mean()
# age               38.438115
# educationno       10.121316
# capitalgain     1092.044064
# capitalloss       88.302311
# hoursperweek      40.931269
# dtype: float64

# %%
sal_train.median()
# Out:
# C:\Users\kiran\AppData\Local\Temp/ipykernel_15688/3812417278.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sal_train.median()
# age             37.0
# educationno     10.0
# capitalgain      0.0
# capitalloss      0.0
# hoursperweek    40.0
# dtype: float64

# %%
sal_train.mode()
# Out:
#    age workclass education  educationno        maritalstatus       occupation  \
# 0   36   Private   HS-grad            9   Married-civ-spouse   Prof-specialty
#
#   relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0      Husband   White   Male            0            0            40
#
#            native  Salary
# 0   United-States   <=50K

# %%
sal_train.skew()
# Out:
# C:\Users\kiran\AppData\Local\Temp/ipykernel_15688/692507889.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sal_train.skew()
# age              0.530180
# educationno     -0.305378
# capitalgain     11.902483
# capitalloss      4.528238
# hoursperweek     0.330856
# dtype: float64

# %%
sal_train.kurt()
# Out:
# C:\Users\kiran\AppData\Local\Temp/ipykernel_15688/1484719101.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sal_train.kurt()
# age              -0.144760
# educationno       0.643605
# capitalgain     153.661174
# capitalloss      19.529284
# hoursperweek      3.167683
# dtype: float64

# %%
sal_train.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.043525     0.080152     0.060278      0.101598
# educationno   0.043525     1.000000     0.124416     0.079691      0.152522
# capitalgain   0.080152     0.124416     1.000000    -0.032218      0.080431
# capitalloss   0.060278     0.079691    -0.032218     1.000000      0.052454
# hoursperweek  0.101598     0.152522     0.080431     0.052454      1.000000

# %%
sal_train.isnull()
# Out:
#          age  workclass  education  educationno  maritalstatus  occupation  \
# 0      False      False      False        False          False       False
# 1      False      False      False        False          False       False
# 2      False      False      False        False          False       False
# 3      False      False      False        False          False       False
# 4      False      False      False        False          False       False
# ...      ...        ...        ...          ...            ...         ...
# 30156  False      False      False        False          False       False
# 30157  False      False      False        False          False       False
# 30158  False      False      False        False          False       False
# 30159  False      False      False        False          False       False
# 30160  False      False      False        False          False       False
#
#        relationship   race    sex  capitalgain  capitalloss  hoursperweek  \
# 0             False  False  False        False        False         False
# 1             False  False  False        False        False         False
# 2             False  False  False        False        False         False
# 3             False  False  False        False        False         False
# 4             False  False  False        False        False         False
# ...             ...    ...    ...          ...          ...           ...
# 30156         False  False  False        False        False         False
# 30157         False  False  False        False        False         False
# 30158         False  False  False        False        False         False
# 30159         False  False  False        False        False         False
# 30160         False  False  False        False        False         False
#
#        native  Salary
# 0       False   False
# 1       False   False
# 2       False   False
# 3       False   False
# 4       False   False
# ...       ...     ...
# 30156   False   False
# 30157   False   False
# 30158   False   False
# 30159   False   False
# 30160   False   False
#
# [30161 rows x 14 columns]

# %%
sal_train.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30156    False
# 30157     True
# 30158    False
# 30159     True
# 30160    False
# Length: 30161, dtype: bool

# %%
sal_train["Salary"]
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
# Categoring dataset as per Salary range :
salary_set = set(sal_train["Salary"])
print(salary_set)
# Out:
# {' <=50K', ' >50K'}

# %%
# As expected transforming :
salary_map = {' >50K':1,' <=50K':0 }
sal_train["Salary"] = sal_train["Salary"].map(salary_map)
sal_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States       0
# 1            0            13   United-States       0
# 2            0            40   United-States       0
# 3            0            40   United-States       0
# 4            0            40            Cuba       0

# %%
sal_train.groupby("education").Salary.mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='education'>

# %%
sal_train.groupby("occupation").Salary.mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='occupation'>

# %%
occupation_set = set(sal_train["occupation"])
print(occupation_set)
# Out:
# {' Farming-fishing', ' Sales', ' Craft-repair', ' Priv-house-serv', ' Exec-managerial', ' Machine-op-inspct', ' Tech-support', ' Other-service', ' Prof-specialty', ' Transport-moving', ' Adm-clerical', ' Protective-serv', ' Handlers-cleaners', ' Armed-Forces'}

# %%
sal_train["occupation"] = sal_train["occupation"].map({' Transport-moving':0, ' Tech-support':1, ' Handlers-cleaners':2, ' Armed-Forces':3, ' Craft-repair':4, ' Machine-op-inspct':5, ' Sales':13, ' Exec-managerial':6, ' Priv-house-serv':8, ' Farming-fishing':7, ' Prof-specialty':9, ' Other-service':11, ' Protective-serv':12, ' Adm-clerical':10}).astype(int) 
sal_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#    occupation    relationship    race      sex  capitalgain  capitalloss  \
# 0          10   Not-in-family   White     Male         2174            0
# 1           6         Husband   White     Male            0            0
# 2           2   Not-in-family   White     Male            0            0
# 3           2         Husband   Black     Male            0            0
# 4           9            Wife   Black   Female            0            0
#
#    hoursperweek          native  Salary
# 0            40   United-States       0
# 1            13   United-States       0
# 2            40   United-States       0
# 3            40   United-States       0
# 4            40            Cuba       0

# %%
sal_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#    occupation    relationship    race      sex  capitalgain  capitalloss  \
# 0          10   Not-in-family   White     Male         2174            0
# 1           6         Husband   White     Male            0            0
# 2           2   Not-in-family   White     Male            0            0
# 3           2         Husband   Black     Male            0            0
# 4           9            Wife   Black   Female            0            0
#
#    hoursperweek          native  Salary
# 0            40   United-States       0
# 1            13   United-States       0
# 2            40   United-States       0
# 3            40   United-States       0
# 4            40            Cuba       0

# %%
occupation_set = set(sal_test["occupation"])
print(occupation_set)
# Out:
# {' Transport-moving', ' Sales', ' Craft-repair', ' Priv-house-serv', ' Machine-op-inspct', ' Protective-serv', ' Exec-managerial', ' Prof-specialty', ' Other-service', ' Tech-support', ' Adm-clerical', ' Handlers-cleaners', ' Farming-fishing', ' Armed-Forces'}

# %%
sal_test["occupation"] = sal_test["occupation"].map({' Transport-moving':0, ' Tech-support':1, ' Handlers-cleaners':2, ' Armed-Forces':3, ' Craft-repair':4, ' Machine-op-inspct':5, ' Sales':13, ' Exec-managerial':6, ' Priv-house-serv':8, ' Farming-fishing':7, ' Prof-specialty':9, ' Other-service':11, ' Protective-serv':12, ' Adm-clerical':10}).astype(int)
sal_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#    occupation    relationship    race    sex  capitalgain  capitalloss  \
# 0           5       Own-child   Black   Male            0            0
# 1           7         Husband   White   Male            0            0
# 2          12         Husband   White   Male            0            0
# 3           5         Husband   Black   Male         7688            0
# 4          11   Not-in-family   White   Male            0            0
#
#    hoursperweek          native  Salary
# 0            40   United-States   <=50K
# 1            50   United-States   <=50K
# 2            40   United-States    >50K
# 3            40   United-States    >50K
# 4            30   United-States   <=50K

# %%
# As expected transforming :
salary_map = {' >50K':1,' <=50K':0 }
sal_test["Salary"] = sal_test["Salary"].map(salary_map)
sal_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#    occupation    relationship    race    sex  capitalgain  capitalloss  \
# 0           5       Own-child   Black   Male            0            0
# 1           7         Husband   White   Male            0            0
# 2          12         Husband   White   Male            0            0
# 3           5         Husband   Black   Male         7688            0
# 4          11   Not-in-family   White   Male            0            0
#
#    hoursperweek          native  Salary
# 0            40   United-States       0
# 1            50   United-States       0
# 2            40   United-States       1
# 3            40   United-States       1
# 4            30   United-States       0

# %%
X_train = sal_train[["educationno","occupation"]]
Y_train = sal_train["Salary"]
X_test = sal_test[["educationno","occupation"]] 
Y_test = sal_test["Salary"]

# %%
from sklearn import svm
from sklearn.svm import SVC

classifier = SVC()
classifier.fit(X_train,Y_train)
# Out:
# SVC()

# %%
score = classifier.score(X_test,Y_test)
print(score)
# Out:
# 0.7768924302788844

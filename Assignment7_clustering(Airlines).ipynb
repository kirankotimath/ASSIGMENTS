# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
df=pd.read_csv("C:\\Users\\kiran\\Downloads\\Airlines+Data.csv")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df1 = df.iloc[:,1:]

# %%
df["Award?"].value_counts()
# Out:
# 0    2518
# 1    1481
# Name: Award?, dtype: int64

# %%
def std_fun(i):
    return (i-i.min())/(i.max()-i.min())

# %%
df_norm=std_fun(df.iloc[:,1:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # H-Clustering:-

# %%
# calculate the distance :-
dist = sch.linkage(df_norm, method='complete')

# %%
dendrogram = sch.dendrogram(dist)

# %%
cluster = AgglomerativeClustering(linkage='complete',n_clusters=4,affinity='euclidean')
cluster
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=4)

# %%
y_cluster = cluster.fit_predict(df_norm)
pd.DataFrame(y_cluster).value_counts()
# Out:
# 0    2526
# 2    1144
# 1     325
# 3       4
# dtype: int64

# %%
df1['h_cluster'] = pd.Series(y_cluster)
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
result1=df1.groupby(y_cluster).mean()
result1
# Out:
#          Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles   Bonus_miles  \
# 0   59791.056611   88.188836   1.703484   1.018606   1.011085  10324.882423
# 1  157084.578462  208.673846   4.661538   1.000000   1.061538  70477.086154
# 2   80173.963287  248.550699   2.104895   1.009615   1.000874  16882.864510
# 3  131999.500000  347.000000   2.500000   1.000000   1.000000  65634.250000
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0     9.192003         230.441013         0.672209        3824.887965
# 1    23.249231        1019.433846         3.196923        5770.572308
# 2    13.412587         739.958916         2.236888        4304.383741
# 3    69.250000       19960.000000        49.250000        2200.250000
#
#      Award?  h_cluster
# 0  0.003167        0.0
# 1  1.000000        1.0
# 2  1.000000        2.0
# 3  1.000000        3.0

# %% [markdown]
# # K-Means Clustering:-

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
kmeans_cluster = KMeans(n_clusters=4)
kmeans_cluster.fit(df_norm)
# Out:
# KMeans(n_clusters=4)

# %%
kmeans_cluster.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
df1 = df1.iloc[:,1:-3]

# %%
df1["Cluster_ID"] = pd.Series(kmeans_cluster.labels_)
df1.head()
# Out:
#    Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0           0          1          1          1          174            1
# 1           0          1          1          1          215            2
# 2           0          1          1          1         4123            4
# 3           0          1          1          1          500            1
# 4           0          4          1          1        43300           26
#
#    Flight_miles_12mo  Flight_trans_12  Cluster_ID
# 0                  0                0           0
# 1                  0                0           0
# 2                  0                0           0
# 3                  0                0           0
# 4               2077                4           1

# %%
k = list(range(1,12,3))
k
TWSS = []
for i in k:
    kmeans=KMeans(n_clusters = i)
    kmeans.fit(df_norm)
    WSS = []
    for j in range(i):
        WSS.append(sum(cdist(df_norm.iloc[kmeans_cluster.labels_==j],kmeans.cluster_centers_[j].reshape(1,df_norm.shape[1]),"euclidean")))
    print("WSS value when k",i,sum(WSS))
    TWSS.append(sum(WSS))
# Out:
# WSS value when k 1 [1018.8337853]
# WSS value when k 4 [2269.32266784]
# WSS value when k 7 [1896.63958062]
# WSS value when k 10 [3310.86827187]

# %%
plt.plot(k,TWSS,"ro-")

# %%
result2 = df1.iloc[:,1:].groupby(df1.Cluster_ID).mean()
result2
# Out:
#             cc1_miles  cc2_miles  cc3_miles   Bonus_miles  Bonus_trans  \
# Cluster_ID
# 0            1.092778   1.017923   1.004217   3335.152873     6.488666
# 1            3.915842   1.001238   1.025990  45609.657178    20.201733
# 2            3.576490   1.001610   1.022544  31282.666667    17.251208
# 3            1.156018   1.032689   1.008915   8850.395245    10.476969
#
#             Flight_miles_12mo  Flight_trans_12  Cluster_ID
# Cluster_ID
# 0                  226.599895         0.658935         0.0
# 1                  713.728960         2.142327         1.0
# 2                  225.352657         0.632850         2.0
# 3                 1030.112927         3.148588         3.0

# %% [markdown]
# # DBSCAN;-

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.8 ,min_samples=20).fit(df_norm)
dbscan
# Out:
# DBSCAN(eps=0.8, min_samples=20)

# %%
pd.Series(dbscan.labels_).value_counts()
# Out:
#  0    2518
#  1    1480
# -1       1
# dtype: int64

# %%
cl=pd.DataFrame(dbscan.labels_)

# %%
cl
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# ...  ..
# 3994  1
# 3995  1
# 3996  1
# 3997  0
# 3998  0
#
# [3999 rows x 1 columns]

# %%
df2=df.iloc[:,0:-1]
df2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df2["Cluster"]=cl
df2
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
print("sillihoette score : %f" %metrics.silhouette_score(df_norm,dbscan.labels_))
# Out:
# sillihoette score : 0.535161

# %%
result3 = df2.iloc[:,1:-1].groupby(df2["Cluster"]).mean()
result3
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Cluster
# -1       160114.000000  500.000000   1.000000   1.000000   1.000000
#  0        59807.839555   87.602462   1.705322   1.013900   1.008737
#  1        97010.442568  240.020946   2.662838   1.015541   1.018243
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Cluster
# -1       71954.000000    86.000000       30817.000000        53.000000
#  0       10227.689039     9.142971         226.292295         0.652502
#  1       28876.327703    15.735135         837.258108         2.565541
#
#          Days_since_enroll
# Cluster
# -1             1373.000000
#  0             3820.652105
#  1             4627.259459

# %%
# from using DBSCAN clustering we get the outliers which are represented by -1
# and we get the four clusters and there mean as per above result3
